# %%
import pandas as pd
import numpy as np
import re
from src.config import BLD, RAW

# %%
columns = {
    'Stkcd': 'stock_id',
    'Accper': 'year',
    "A001000000": "size",
    'A001101000': 'cash',  # 货币资金
    'A002101000': 'short_term_debt',  # 短期借款
    'A002125000': 'current_portion_long_debt',  # 一年内到期的长期借款
    'A002201000': 'long_term_debt',  # 长期借款
    'A002203000': 'bonds_payable',  # 应付债券
    'A002211000': 'lease_liabilities'
    }
df1 = pd.read_csv(RAW / 'csmar/基本信息/资产负债表/FS_Combas.csv',
                     usecols=columns.keys(), dtype={'Stkcd': str}).rename(columns=columns)
df1
# Out:
#       stock_id        year          cash          size  short_term_debt  \
# 0       000002  2012-12-31  5.229154e+10  3.788016e+11     9.932400e+09
# 1       000002  2013-12-31  4.436541e+10  4.792053e+11     5.102515e+09
# 2       000002  2014-12-31  6.271525e+10  5.084088e+11     2.383070e+09
# 3       000002  2015-12-31  5.318038e+10  6.112956e+11     1.900088e+09
# 4       000002  2016-12-31  8.703212e+10  8.306742e+11     1.657659e+10
# ...        ...         ...           ...           ...              ...
# 23268   920819  2015-12-31  3.062411e+09  8.758899e+09     1.158312e+09
# 23269   920819  2016-12-31  3.091401e+09  1.168145e+10     3.589184e+09
# 23270   920819  2017-12-31  3.580529e+09  1.376790e+10     2.896739e+09
# 23271   920819  2018-12-31  1.841292e+09  1.187122e+10     2.117293e+09
# 23272   920819  2019-12-31  1.493290e+09  1.130712e+10     2.428895e+09
#
#        current_portion_long_debt  long_term_debt  bonds_payable  \
# 0                   2.562496e+10    3.603607e+10   0.000000e+00
# 1                   2.752179e+10    3.668313e+10   7.398392e+09
# 2                   2.044929e+10    3.453671e+10   1.161223e+10
# 3                   2.474640e+10    3.382858e+10   1.901581e+10
# 4                   2.677330e+10    5.640606e+10   2.910838e+10
# ...                          ...             ...            ...
# 23268               0.000000e+00    2.252060e+09   0.000000e+00
# 23269               1.040550e+09             NaN            NaN
# 23270               9.801300e+07    1.374927e+09   1.189154e+09
# 23271                        NaN    1.428159e+09   1.191109e+09
# 23272               1.344661e+09             NaN   1.193200e+09
#
#        lease_liabilities
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 23268                NaN
# 23269                NaN
# 23270                NaN
# 23271                NaN
# 23272                NaN
#
# [23273 rows x 9 columns]

# %%
columns = {
     'Symbol': 'stock_id',
    'EndDate': 'year',
    'MarketValue': 'market_cap'
    }

df2 = pd.read_csv(RAW / 'csmar/基本信息/上市公司资本结构表/EVA_Structure.csv',
                     usecols=columns.keys(), dtype={'Symbol': str}).rename(columns=columns)

df2
# Out:
#       stock_id        year    market_cap
# 0       000002  2012-12-31  1.112953e+11
# 1       000002  2013-12-31  9.040071e+10
# 2       000002  2014-12-31  1.534214e+11
# 3       000002  2015-12-31  2.699909e+11
# 4       000002  2016-12-31  2.268546e+11
# ...        ...         ...           ...
# 21829   688368  2019-12-31  5.450368e+09
# 21830   688369  2019-12-31  4.523908e+09
# 21831   688388  2019-12-31  1.308374e+10
# 21832   688389  2019-12-31  6.932524e+09
# 21833   688399  2019-12-31  3.394098e+09
#
# [21834 rows x 3 columns]

# %%
# 先重命名并提取 df1 的关键字段
df1_ev = df1.copy()
df1_ev['year'] = pd.to_datetime(df1_ev['year']).dt.year

# 计算有息负债
df1_ev['interest_bearing_debt'] = (
    df1_ev['short_term_debt'].fillna(0) +
    df1_ev['current_portion_long_debt'].fillna(0) +
    df1_ev['long_term_debt'].fillna(0) +
    df1_ev['bonds_payable'].fillna(0) +
    df1_ev['lease_liabilities'].fillna(0)
)

# 准备 df2，提取并重命名市值字段
df2_ev = df2.copy()
df2_ev['year'] = pd.to_datetime(df2_ev['year']).dt.year

# 合并两个表
df_merged = pd.merge(df1_ev[['stock_id', 'year', 'interest_bearing_debt', 'cash', 'size']],
                     df2_ev[['stock_id', 'year', 'market_cap']],
                     on=['stock_id', 'year'], how='inner')

# 计算 EV
df_merged['ev'] = df_merged['market_cap'] + df_merged['interest_bearing_debt'] - df_merged['cash'].fillna(0)
df_merged['tobinq'] = (df_merged['market_cap'] + df_merged['interest_bearing_debt']) / df_merged['size']

# %%
df_merged
# Out:
#       stock_id  year  interest_bearing_debt          cash          size  \
# 0       000002  2012           7.159343e+10  5.229154e+10  3.788016e+11
# 1       000002  2013           7.670583e+10  4.436541e+10  4.792053e+11
# 2       000002  2014           6.898130e+10  6.271525e+10  5.084088e+11
# 3       000002  2015           7.949089e+10  5.318038e+10  6.112956e+11
# 4       000002  2016           1.288643e+11  8.703212e+10  8.306742e+11
# ...        ...   ...                    ...           ...           ...
# 21829   688368  2019           0.000000e+00  1.392377e+08  1.372367e+09
# 21830   688369  2019           0.000000e+00  7.680927e+08  1.683374e+09
# 21831   688388  2019           0.000000e+00  7.012417e+08  2.653761e+09
# 21832   688389  2019           6.000000e+05  8.199537e+08  1.178961e+09
# 21833   688399  2019           0.000000e+00  2.486915e+08  1.154362e+09
#
#          market_cap            ev    tobinq
# 0      1.112953e+11  1.305971e+11  0.482809
# 1      9.040071e+10  1.227411e+11  0.348716
# 2      1.534214e+11  1.596874e+11  0.437449
# 3      2.699909e+11  2.963014e+11  0.571707
# 4      2.268546e+11  2.686868e+11  0.428229
# ...             ...           ...       ...
# 21829  5.450368e+09  5.311130e+09  3.971510
# 21830  4.523908e+09  3.755815e+09  2.687406
# 21831  1.308374e+10  1.238250e+10  4.930264
# 21832  6.932524e+09  6.113170e+09  5.880705
# 21833  3.394098e+09  3.145407e+09  2.940236
#
# [21834 rows x 8 columns]

# %%
df_merged.isna().sum()
# Out:
# stock_id                 0
# year                     0
# interest_bearing_debt    0
# cash                     0
# size                     0
# market_cap               0
# ev                       0
# tobinq                   0
# dtype: int64

# %%
output_path = BLD / 'ev.parquet'
df_merged.to_parquet(output_path, index=False)
